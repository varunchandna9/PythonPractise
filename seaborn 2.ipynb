# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips_df=sns.load_dataset("tips")

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x="total_bill",y="tip",data=tips_df,hue="day")

# %%
sns.relplot(x="total_bill",y="tip",data=tips_df,hue="day",style="size",size="sex",sizes=(25,200))

# %%
sns.relplot(x="tip",y="total_bill",data=tips_df,kind="line",ci="sd")

# %%
sns.relplot(x="tip",y="total_bill",data=tips_df,kind="line",ci="sd",estimator=None)

# %%
sns.relplot(x="tip",y="total_bill",data=tips_df,hue="sex",style="day")

# %%
sns.relplot(x="tip",y="total_bill",data=tips_df,kind="line",ci=None,estimator=None,hue="sex",style="day")

# %%
sns.relplot(x="tip",y="total_bill",data=tips_df,kind="line",ci=None,estimator=None,hue="sex",style="day",col="day",col_wrap=2)

# %%
sns.relplot(x="tip",y="total_bill",data=tips_df,hue="sex",style="day",col="sex",row="day")

# %%
sns.catplot(y="tip",x="day",data=tips_df,jitter=False)

# %%
sns.catplot(y="tip",x="day",data=tips_df)

# %%
sns.catplot(y="tip",x="day",data=tips_df.query("tip>1"),jitter=False)

# %%
sns.catplot(y="tip",x="day",data=tips_df,kind="swarm")
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(y="tip",x="day",data=tips_df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.catplot(y="tip",x="day",data=tips_df,kind="box",hue="sex",hue_order=["Female","Male"])

# %%
sns.catplot(y="tip",x="day",data=tips_df,row="day")

# %%
sns.catplot(y="tip",x="day",data=tips_df,col="day")

# %%
sns.catplot(y="tip",x="day",data=tips_df,row="day",col="size")

# %%
sns.catplot(y="tip",x="day",data=tips_df,kind="violin")

# %%
sns.catplot(y="tip",x="day",data=tips_df,kind="violin",hue="sex",inner="sticks")

# %%
sns.catplot(y="tip",x="day",data=tips_df,kind="bar",hue="sex",col="sex")

# %%
sns.catplot(y="tip",x="day",data=tips_df,kind="point",hue="sex",row="smoker")

# %%
sns.distplot(tips_df["total_bill"])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips_df["tip"],kde=False)
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip'>

# %%
sns.distplot(tips_df["tip"])
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.distplot(tips_df["tip"],rug=True)
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.distplot(tips_df["tip"],bins=100,rug=True)
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.distplot(tips_df.total_bill[(tips_df.total_bill>15) & (tips_df.total_bill<20)],kde=False)
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.kdeplot(tips_df["total_bill"],bw=1000)
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 1000 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips_df["total_bill"],rug=True)
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
from scipy import stats

# %%
a=np.random.gamma(9,size=200)

# %%
sns.distplot(a,fit=stats.gamma)
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
a=np.random.beta(7,7,size=200)

# %%
sns.distplot(a,fit=stats.beta,kde=False)
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:>

# %%
sns.jointplot(y="tip",x="day",data=tips_df)

# %%
sns.jointplot(y="tip",x="total_bill",data=tips_df)

# %%
sns.jointplot(y="tip",x="sex",data=tips_df)

# %%
sns.jointplot(y="tip",x="total_bill",data=tips_df,kind="hex")

# %%
sns.jointplot(y="size",x="total_bill",data=tips_df,kind="hex")

# %%
sns.jointplot(y="total_bill",x="size",data=tips_df,kind="kde")

# %%
sns.pairplot(data=tips_df,hue="sex")
